# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import seaborn as sns

# %%
data = pd.read_excel('USD_INR.xlsx')
print(data.head())
print(data.describe())
# Out:
#    YEAR  Conversion Rate  Inflation Rate of India  Inflation Rate of USA  \
# 0  2002            48.61                   0.0430                 0.0159
# 1  2003            46.58                   0.0381                 0.0227
# 2  2004            45.32                   0.0377                 0.0268
# 3  2005            44.10                   0.0425                 0.0339
# 4  2006            45.31                   0.0580                 0.0323
#
#    Trade Balance of India  Trade Balance of USA  GDP Growth of India   \
# 0                   -5.05               -439.75                0.0380
# 1                   -4.23               -521.96                0.0786
# 2                  -12.66               -634.14                0.0792
# 3                  -22.90               -739.90                0.0792
# 4                  -29.98               -786.45                0.0806
#
#    GDP Growth of USA  Global GDP Growth  Government Effectiveness of India  \
# ...

# %%
# Correlation
correlation_matrix = data.corr()
conversion_correlations = correlation_matrix['Conversion Rate']
print(conversion_correlations)
# Out:
# YEAR                                 0.928128
# Conversion Rate                      1.000000
# Inflation Rate of India             -0.275127
# Inflation Rate of USA                0.219599
# Trade Balance of India              -0.370748
# Trade Balance of USA                -0.200089
# GDP Growth of India                 -0.265112
# GDP Growth of USA                    0.009854
# Global GDP Growth                   -0.189066
# Government Effectiveness of India    0.687875
# Government Effectiveness of USA     -0.822976
# Political Stability of India         0.828012
# Political Stability of USA          -0.232280
# Name: Conversion Rate, dtype: float64

# %%
# Multiple Linear Regression

#Independent Variables
X = df[
    [
        "Inflation Rate of India",
        "Inflation Rate of USA",
        "Trade Balance of India",
        "Trade Balance of USA",
        "GDP Growth of India",
        "GDP Growth of USA",
        "Global GDP Growth",
        "Government Effectiveness of India",
        "Government Effectiveness of USA",
        "Political Stability of India",
        "Political Stability of USA",
    ]
]
y = df["Conversion Rate"] # Dependent Variable

X = sm.add_constant(X) # Constant to independent variables

# Fitting the linear regression model
model = sm.OLS(y, X).fit()

# Model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:        Conversion Rate   R-squared:                       0.946
# Model:                            OLS   Adj. R-squared:                  0.880
# Method:                 Least Squares   F-statistic:                     14.35
# Date:                Sat, 12 Oct 2024   Prob (F-statistic):           0.000213
# Time:                        03:10:29   Log-Likelihood:                -52.122
# No. Observations:                  21   AIC:                             128.2
# Df Residuals:                       9   BIC:                             140.8
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...
